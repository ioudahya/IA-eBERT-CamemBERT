# %%
# !pip install torch
# !pip install transformers

# %%
from transformers import pipeline

nlp = pipeline("fill-mask", 'bert-base-cased')
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/416M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]

# %%
nlp("The man worked as a [MASK].")
# Out:
# [{'score': 0.04804684966802597,
#   'sequence': 'The man worked as a lawyer.',
#   'token': 4545,
#   'token_str': 'lawyer'},
#  {'score': 0.037494439631700516,
#   'sequence': 'The man worked as a waiter.',
#   'token': 17989,
#   'token_str': 'waiter'},
#  {'score': 0.03551263362169266,
#   'sequence': 'The man worked as a cop.',
#   'token': 9947,
#   'token_str': 'cop'},
#  {'score': 0.03127165883779526,
#   'sequence': 'The man worked as a detective.',
#   'token': 9140,
#   'token_str': 'detective'},
#  {'score': 0.027423148974776268,
#   'sequence': 'The man worked as a doctor.',
#   'token': 3995,
#   'token_str': 'doctor'}]

# %%
nlp("The best thing since sliced [MASK].")
# Out:
# [{'score': 0.237198144197464,
#   'sequence': 'The best thing since sliced open.',
#   'token': 1501,
#   'token_str': 'open'},
#  {'score': 0.07578453421592712,
#   'sequence': 'The best thing since sliced off.',
#   'token': 1228,
#   'token_str': 'off'},
#  {'score': 0.05955592915415764,
#   'sequence': 'The best thing since sliced up.',
#   'token': 1146,
#   'token_str': 'up'},
#  {'score': 0.04394252970814705,
#   'sequence': 'The best thing since sliced bread.',
#   'token': 8162,
#   'token_str': 'bread'},
#  {'score': 0.03836282715201378,
#   'sequence': 'The best thing since sliced meat.',
#   'token': 6092,
#   'token_str': 'meat'}]
